# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1.AN INSTITUTION WISHES TO FIND OUT THEIR STUDENTS ABILITY IN MATHEMATICS, READING AND WRITING SKILLS

# %%
data=pd.read_csv('Students_Performance .csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#1) To find the no. of males and females participated in the exam
male_count = len(data[data['gender'] == 'male'])
female_count = len(data[data['gender'] == 'female'])

# %%
male_count
# Out:
# 482

# %%
female_count
# Out:
# 518

# %%
#2) Parental level of education
data['parental level of education'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#c) Who scores the most on average for math, reading and writing based on
#      i) Gender
data.groupby('gender').mean()[['math score', 'reading score', 'writing score']]
# Out:
# <ipython-input-21-88ccef490059>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('gender').mean()[['math score', 'reading score', 'writing score']]
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
#        ii.Test preparation course
data.groupby('test preparation course').mean()[['math score', 'reading score', 'writing score']]
# Out:
# <ipython-input-22-7d737f199152>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('test preparation course').mean()[['math score', 'reading score', 'writing score']]
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
#d) scoring variation for math, reading and writing based on

#         i.Gender

data.groupby('gender').std()[['math score', 'reading score', 'writing score']]
# Out:
# <ipython-input-23-0cfd6e152474>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('gender').std()[['math score', 'reading score', 'writing score']]
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %%
#        ii.Test preparation course

data.groupby('test preparation course').std()[['math score', 'reading score', 'writing score']]
# Out:
# <ipython-input-24-de3050705edb>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('test preparation course').std()[['math score', 'reading score', 'writing score']]
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %%
#the top 25% of students based on their math score

top_25_threshold = data['math score'].quantile(0.75)
top_students = data[data['math score'] > top_25_threshold]

# %%
top_students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 430  female        group A                some college      standard
# 431  female        group B           bachelor's degree  free/reduced
# 432  female        group D           bachelor's degree      standard
# 433  female        group D                 high school      standard
# 434  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
top_students.shape
# Out:
# (231, 8)

# %% [markdown]
# QUESTION NO. 2
# CASE STUDY ON TESTING A HYPOTHESIS

# %%
#1. Testing for an Increase in Sales Due to Digital Marketing:
#     a. Hypothesis Setup:

# %% [markdown]
# H0: There is no significant increase in sales after digital marketing.
#
# HA: There is a significant increase in sales after digital marketing.

# %%
sales_data=pd.read_csv('Sales_add.csv')

# %%
sales_data.columns
# Out:
# Index(['Month', 'Region', 'Manager', 'Sales_before_digital_add(in $)',
#        'Sales_After_digital_add(in $)'],
#       dtype='object')

# %%
sales_data.shape
# Out:
# (22, 5)

# %%
sales_data.describe

# %%
#b. Test Procedure
from scipy.stats import ttest_rel

# %%
alpha=0.05
t_statistic, p_value = ttest_rel(sales_data['Sales_After_digital_add(in $)'],sales_data['Sales_before_digital_add(in $)'],alternative='greater')

# Check p-value to determine the outcome of the hypothesis test
if p_value < 0.05:
    print("Reject the null hypothesis. There is a significant increase in sales after digital marketing.")
else:
    print("Fail to reject the null hypothesis. There isn't enough evidence to suggest a significant increase in sales.")
# Out:
# Reject the null hypothesis. There is a significant increase in sales after digital marketing.

# %% [markdown]
# COMPANY NEEDS TO CHECK WHETHER THERE IS ANY DEPENDENCY BETWEEN THE FEATURES 'REGION' AND 'MANAGER'

# %%
from scipy.stats import chi2_contingency


contingency_table = pd.crosstab(sales_data['Region'], sales_data['Manager'])

chi2, p_value, _, _ = chi2_contingency(contingency_table)

# Check p-value to determine the outcome of the hypothesis test
if p_value < 0.05:
    print("Reject the null hypothesis. There is a dependency between 'Region' and 'Manager'.")
else:
    print("Fail to reject the null hypothesis. There isn't enough evidence to suggest a dependency between 'Region' and 'Manager'.")
# Out:
# Fail to reject the null hypothesis. There isn't enough evidence to suggest a dependency between 'Region' and 'Manager'.
